# %%
import js2py as js

# %%
js.translate_file('databaseCourse/elements/pl-relax-element/renderer.js', 'relalg_bundle.py')
# Out:
# ---------------------------------------------------------------------------
# Ecma51NotSupported                        Traceback (most recent call last)
# File ~\miniconda3\lib\site-packages\pyjsparser\parser.py:3008, in PyJsParser.parse(self, code, options)
#    3007 try:
# -> 3008     program = self.parseProgram()
#    3009 except Ecma51NotSupported as e:
#
# File ~\miniconda3\lib\site-packages\pyjsparser\parser.py:2974, in PyJsParser.parseProgram(self)
#    2972 node = Node()
# -> 2974 body = self.parseScriptBody()
#    2975 return node.finishProgram(body)
#
# File ~\miniconda3\lib\site-packages\pyjsparser\parser.py:2963, in PyJsParser.parseScriptBody(self)
#    2962 while (self.startIndex < self.length):
# -> 2963     statement = self.parseStatementListItem()
#    2964     # istanbul ignore if
#
# File ~\miniconda3\lib\site-packages\pyjsparser\parser.py:2110, in PyJsParser.parseStatementListItem(self)
#    2109         return self.parsePyimportStatement()
# ...
